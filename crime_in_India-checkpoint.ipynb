# %% [markdown]
# # DATA ANALYSIS OF CRIME AGAINST WOMEN IN INDIA IN 2013

# %% [markdown]
# # Import needed modules and get the required dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#getting the crime against women in 2013 dataset
crime_data=pd.read_csv('Downloads/cprsvCAW_2_2013.csv')
crime_data
# Out:
#               STATE/UT                                              CRIME  \
# 0       Andhra Pradesh  Assault on women with intent to outrage her Mo...
# 1    Arunachal Pradesh  Assault on women with intent to outrage her Mo...
# 2                Assam  Assault on women with intent to outrage her Mo...
# 3                Bihar  Assault on women with intent to outrage her Mo...
# 4         Chhattisgarh  Assault on women with intent to outrage her Mo...
# ..                 ...                                                ...
# 451           Delhi UT                         Total Crimes against Women
# 452        Lakshadweep                         Total Crimes against Women
# 453         Puducherry                         Total Crimes against Women
# 454        Total (UTs)                         Total Crimes against Women
# 455  Total (All-India)                         Total Crimes against Women
#
#      CASES REGISTERED  CASES CHARGESHEETED  CASES CONVICTED  PERSONS ARRESTED  \
# ...

# %%
#checking the total categories in crime
crime_data['CRIME'].value_counts()
# Out:
# Indecent Representation of Women (P) Act              38
# Rape                                                  38
# Total Crimes against Women                            38
# Insult to the modesty of Women                        38
# Immoral Traffic (P) Act                               38
# Importation of Girls from Foreign Country             38
# Assault on women with intent to outrage her Modest    38
# Dowry Prohibition Act                                 38
# Commission of Sati (P) Act                            38
# Kidnapping & Abduction of Women & Grils               38
# Dowry Deaths                                          38
# Cruelty by Husband or his relatives                   38
# Name: CRIME, dtype: int64

# %% [markdown]
# There are total 11 different types of crimes against women in India

# %%
#remove Total UTs,States,All-India rows
temp=crime_data.groupby(['STATE/UT','CRIME']).sum()
temp.drop(index=['Total (All-India)','Total (States)','Total (UTs)'],inplace=True)
temp.head(12)
# Out:
#                                                                 CASES REGISTERED  \
# STATE/UT    CRIME
# A&N Islands Assault on women with intent to outrage her Modest                45
#             Commission of Sati (P) Act                                         0
#             Cruelty by Husband or his relatives                                9
#             Dowry Deaths                                                       1
#             Dowry Prohibition Act                                              0
#             Immoral Traffic (P) Act                                            4
#             Importation of Girls from Foreign Country                          0
#             Indecent Representation of Women (P) Act                           0
#             Insult to the modesty of Women                                     8
#             Kidnapping & Abduction of Women & Grils                           12
# ...

# %%
#groupby crime and then group by states
grouped_crime=temp.groupby(['CRIME','STATE/UT']).sum()
grouped_crime
# Out:
#                                                                       CASES REGISTERED  \
# CRIME                                              STATE/UT
# Assault on women with intent to outrage her Modest A&N Islands                      45
#                                                    Andhra Pradesh                 6930
#                                                    Arunachal Pradesh                93
#                                                    Assam                          2409
#                                                    Bihar                           331
# ...                                                                                ...
# Total Crimes against Women                         Tamil Nadu                     7475
#                                                    Tripura                        1628
#                                                    Uttar Pradesh                 32546
# ...

# %%
#create a df which only contains top 10 states with highest total people arrested for crime against women
total_crime=pd.DataFrame(grouped_crime.loc['Total Crimes against Women',:])
top_10=total_crime.sort_values(['PERSONS ARRESTED'],axis=0,ascending=False).head(10)
top_10
# Out:
#                 CASES REGISTERED  CASES CHARGESHEETED  CASES CONVICTED  \
# STATE/UT
# Uttar Pradesh              32546                21868             5672
# Maharashtra                24895                20301              768
# Andhra Pradesh             32809                26002             2228
# West Bengal                29826                30112              609
# Madhya Pradesh             22061                19729             4220
# Gujarat                    12283                11263              217
# Bihar                      13609                 9448              812
# Rajasthan                  27933                14473             3192
# Karnataka                  12027                 9733              369
# Odisha                     14173                12094              428
#
#                 PERSONS ARRESTED  PERSONS CHARGESHEETED  PERSONS CONVICTED
# STATE/UT
# Uttar Pradesh             100021                  59248              13653
# ...

# %% [markdown]
# These are the top 10 states in India that have high numbers of crimes against women, than other parts of India.

# %%
#visualising the crime of 'Assault on women with intent to outrage her modest' in each state
grouped_crime.loc['Assault on women with intent to outrage her Modest',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.style.use('seaborn-whitegrid')
plt.title('Crime : Assault on women with intent to outrage her Modest')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The crime of Assault on women with intent to outrage her Modest :

# %% [markdown]
# 1)The state having highest number of registered cases is Madhya Pradesh and Maharashtra, Uttar Pradesh had almost the same number of registered cases as MP and Maharashtra.The places with least number of crimes in this category are not states but all the islands.

# %% [markdown]
# 2)The total number of people arrested in this crime is greater than the total registered cases. This can be seen in almost all places.

# %% [markdown]
# 3)The total people convicted are very less among the total people arrested ,it seems like most of the arrested people were chargesheeted instead.

# %% [markdown]
# 4)Delhi has less population than many states like Tamil Nadu,still has relatively higher crime in this category.

# %% [markdown]
# 5)The number of crimes in this category is more in the Northern part of India as compared to the Southern part.

# %%
#visualising the crime of 'Commission of Sati act' in each state
grouped_crime.loc['Commission of Sati (P) Act',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Commission of Sati (P) Act')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Not a SINGLE state/UT in INDIA has recorded crime under 'Commission of Sati Act' in 2013.

# %%
#visualising the crime of 'Cruelty by Husband or his relatives' in each state
grouped_crime.loc['Cruelty by Husband or his relatives',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Cruelty by Husband or his relatives')
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The crime of Cruelty by Husband or his relatives :
#
# 1)The state having highest number of registered cases is West Bengal and Andhra Pradesh, Rajasthan had almost the same number of registered cases as WB and AP.Despite having highest registered cases,the overall crime of this type is the highest in UP, followed by Maharashtra. The places with least number of crimes in this category are not states but all the islands. Sikkim, Manipur, Nagaland, Mizoram, Puducherry (eastern states) had no cases recorded at all.
#
# 2)The total number of people arrested in this crime is greater than the total registered cases. This can be seen in almost all places.
#
# 3)The total people convicted are very less among the total people arrested ,it seems like most of the arrested people were chargesheeted instead.
#
# 4)The overall number of crimes in this category is more in the Central part of India ,followed by Southern part and then by Northen part.

# %%
#visualising the crime of 'Dowry Deaths' in each state
grouped_crime.loc['Dowry Deaths',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Dowry Deaths')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The crime of Dowry Deaths :
#
# 1)The state having highest number of cases is UP. Bihar is second highest,but there is a huge gap between UP and Bihar. Surprisingly this time Maharashtra recorded lower cases than before types of crimes. The places with least number of crimes in this category are not states but all the islands. Sikkim, Manipur, Nagaland, Mizoram, Puducherry (eastern states) had no cases recorded at all.
#
# 2)The total number of people arrested in this crime is greater than the total registered cases. This can be seen in almost all places.
#
# 3)The total people convicted are very less among the total people arrested ,it seems like most of the arrested people were chargesheeted instead.
#
# 4)The overall number of crimes in this category is more in the Northen part of India ,followed by Central part and then by Southern part. But there is a huge gap between Northen part and other parts. The Govt. of UP needs to work on campaigns to spread awareness and ultimately bring the wrong stereotypical mindsets of its people down.

# %%
#visualising the crime of 'Dowry Prohibition Act' in each state
grouped_crime.loc['Dowry Prohibition Act',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Dowry Prohibition Act')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# Crimes under the Dowry Prohibition Act :
#
# 1)The Northen States have once again shown their huge contribution in crime against women. This time Odisha, Andhra Pradesh has also shown great participation.
#
# 2)The total number of people arrested in this crime is greater than the total registered cases. This can be seen in almost all places.
#
# 3)The total people convicted are very less among the total people arrested ,it seems like most of the arrested people were chargesheeted instead.

# %%
#visualising the crime of 'Immoral Traffic (P) Act' in each state
grouped_crime.loc['Immoral Traffic (P) Act',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Immoral Traffic (P) Act')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# The crime under Immoral Traffic Act:
#
# 1)The Southern states show high participation in this crime.There is a huge gap in the overall crime between the Southern states and central states. Its nice to know Northen states have participated less in this crime.
#
# 2)The total number of people arrested in this crime is greater than the total registered cases. This can be seen in almost all places.
#
# 3)The total people convicted are very less among the total people arrested ,it seems like most of the arrested people were chargesheeted instead.

# %%
#visualising the crime of 'Importation of Girls from Foreign Country' in each state
grouped_crime.loc['Importation of Girls from Foreign Country',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Importation of Girls from Foreign Country')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# The crime of importing girls from foreign countries:
#
# It is clearly seen that only few states are participating in this crime. Highest crime recorded in MP,WB . Followed by Bihar.

# %%
#visualising the crime of 'Indecent Representation of Women (P) Act' in each state
grouped_crime.loc['Indecent Representation of Women (P) Act',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Indecent Representation of Women (P) Act')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# The crime under Indecent Representation of Women Act:
#
# Andhra Pradesh had odly highest number of such crime recorded.Followed by Rajasthan.Rest all states had no records for such crime.

# %%
#visualising the crime of 'Insult to the modesty of Women' in each state
grouped_crime.loc['Insult to the modesty of Women',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Insult to the modesty of Women')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# The crime of Insult to the modesty of women:
#
# The people of AP had been indulged heavily in this crime, followed by the people of Maharashtra.Delhi has relatively way higher number of recored cases in such crime.

# %%
#visualising the crime of 'Kidnapping & Abduction of Women & Grils' in each state
grouped_crime.loc['Kidnapping & Abduction of Women & Grils',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Kidnapping & Abduction of Women & Grils')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# The crime of Kidnapping & Abduction of Women and girls :
#
# The people of UP had indulged in this crime in huge numbers as compared to any other state. Bihar again a Northen state has second highest records. WB is not far behind from Bihar.

# %%
#visualising the crime of 'Rape' in each state
grouped_crime.loc['Rape',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Crime : Rape')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# The crime of Rape:
#
# This crime seems 'popular' among many states.Obviously Northern,Southern and Central parts of India has most records.But surprisingly, Islands and many samll Eastern states like sikkim, which had shown almost no crime records till now, had shown records of this crime.
#
# Madhya Pradesh had maximum records followed by UP then Maharashtra.
#
# Delhi again had relatively higher records than other states whose population is higher than Delhi.

# %%
#visualising the crime of 'Total Crimes against Women' in each state
grouped_crime.loc['Total Crimes against Women',:].plot(kind='bar',stacked=True,figsize= (10, 5))
plt.title('Total Crimes against Women')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()

# %% [markdown]
# The Top 3 state wise 'leader-board-positions' in Total crime against women in INDIA for the year 2013 are :
#
# 1)Utter Pradesh
#
# 2)Andhra Pradesh & Maharashtra (they only had a difference of few cases ,that is neglected here)
#
# 3)West Bengal & Madhya Pradesh
#
# This is a LeaderBoard where NO-ONE would like to end up among the tops.

# %% [markdown]
# # Conclusion

# %% [markdown]
# There was a huge amount of Crime against Women in INDIA in year 2013. Although on the Bright side,the overall crime was lower as compared to the overall population of the country. The people in the Northern, Central and Southern part contributed maximum number of recored cases.
#
# The Islands & the extreme eastern states had recorded very very low criminal cases. Does this mean that people in these places show more respect towards women, or the women in these places are more afraid to go out and file cases against people who illtreat/torture them ? Well, this data does not clearly give us a proper explaination for that.
